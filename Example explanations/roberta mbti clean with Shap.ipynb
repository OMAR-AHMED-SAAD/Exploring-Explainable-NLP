# %%
# !nvidia-smi
# Out:
# Thu May  2 05:49:02 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.78                 Driver Version: 551.78         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   36C    P0             22W /   80W |       0MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Roberta Base Model

# %%
import os
import pandas as pd
import numpy as np

import torch
from torch.utils.data import Dataset, DataLoader, random_split

from transformers import AutoTokenizer, AutoModel

# %%
# setting the model name
PRE_TRAINED_MODEL_NAME = 'roberta-base'

# setting the dataset
dataset='MBTI 500 multi_label.csv'


# setting the data path
if os.path.exists(f'/datasets/mbti/{dataset}'):
    DATAPATH=f'/datasets/mbti/{dataset}'
else:
    DATAPATH=f'../data/{dataset}'

# setting the checkpoint path 
if os.path.exists('ckpts'):
    CHECKPOINTPATH = 'ckpts/Persnality_MBTI'
else:
    CHECKPOINTPATH = '../ckpts/Persnality_MBTI'

# training parameters
MAX_LEN = 512
TRAIN_BATCH_SIZE = 20
VALID_BATCH_SIZE = 16
TEST_BATCH_SIZE = 16
EPOCHS = 10
THRESHOLD = 0.5 # threshold for the sigmoid function

# TOKENIZER
tokenizer = AutoTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)

# setting the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# setting the random seed
torch.manual_seed(99)
torch.cuda.manual_seed(99)
torch.cuda.manual_seed_all(99)
np.random.seed(99)

# %%
DATAPATH,CHECKPOINTPATH
# Out:
# ('../data/MBTI 500 multi_label.csv', '../ckpts/Persnality_MBTI')

# %% [markdown]
# ### Loading the Data

# %%
# load the data
data = pd.read_csv(DATAPATH,encoding='utf-8')

# %%
# get the labels list
labels_list = data.columns[2:].tolist()
print(f'Labels list: {labels_list}')
# Out:
# Labels list: ['IE', 'NS', 'TF', 'JP']

# %% [markdown]
# #### Load the model

# %%
# import model
import sys
sys.path.append('../Models')
import MBTI_model_shap as model
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
model_no_words = model.ROBERTAClass(PRE_TRAINED_MODEL_NAME)
model_no_words.load_state_dict(torch.load(CHECKPOINTPATH + f'_clean_Best_{PRE_TRAINED_MODEL_NAME}.bin', map_location=torch.device(device)))
model_no_words.to(device)
print(f'{PRE_TRAINED_MODEL_NAME}_no_words loaded')
model_no_words.eval()

torch.set_grad_enabled(False)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# roberta-base_no_words loaded

# %% [markdown]
# ### SHAP

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# ### Calculate the SHAP values

# %%
text= "I am a very shy person and I prefer to be alone."

# %%
# shap values "call the model.explain method with the model, text data to explain and aspect"
shap_values_IE= model.explain_model(model_no_words,[text],aspect='IE')

# %%
text2="I think people are generally good and I trust them. I am very empathetic and I like to help others. I am very compassionate and I like to make others feel good."

# %%
shap_values_TF= model.explain_model(model_no_words,[text2],aspect='TF')

# %%
model_no_words.getProbabilities(np.array([text]))
# Out:
# tensor([[0.0655, 0.2378, 0.3937, 0.2727]], device='cuda:0')

# %% [markdown]
# ### Plot the shap values

# %%
shap.plots.text(shap_values_IE)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_kzstzxmalfefmazndmhy = '_tp_kzstzxmalfefmazndmhy_output_0';
#     document._zoom_kzstzxmalfefmazndmhy = undefined;
#     function _output_onclick_kzstzxmalfefmazndmhy(i) {
#         var next_id = undefined;
#
#         if (document._zoom_kzstzxmalfefmazndmhy !== undefined) {
#             document.getElementById(document._zoom_kzstzxmalfefmazndmhy+ '_zoom').style.display = 'none';
#
#             if (document._zoom_kzstzxmalfefmazndmhy === '_tp_kzstzxmalfefmazndmhy_output_' + i) {
#                 document.getElementById(document._zoom_kzstzxmalfefmazndmhy).style.display = 'block';
#                 document.getElementById(document._zoom_kzstzxmalfefmazndmhy+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_kzstzxmalfefmazndmhy).style.display = 'none';
#                 document.getElementById(document._zoom_kzstzxmalfefmazndmhy+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_kzstzxmalfefmazndmhy !== '_tp_kzstzxmalfefmazndmhy_output_' + i) {
#             next_id = '_tp_kzstzxmalfefmazndmhy_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_kzstzxmalfefmazndmhy = next_id;
#     }
#     function _output_onmouseover_kzstzxmalfefmazndmhy(i, el) {
#         if (document._zoom_kzstzxmalfefmazndmhy !== undefined) { return; }
#         if (document._hover_kzstzxmalfefmazndmhy !== undefined) {
#             document.getElementById(document._hover_kzstzxmalfefmazndmhy + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_kzstzxmalfefmazndmhy).style.display = 'none';
#         }
#         document.getElementById('_tp_kzstzxmalfefmazndmhy_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_kzstzxmalfefmazndmhy = '_tp_kzstzxmalfefmazndmhy_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_kzstzxmalfefmazndmhy_output_0_name"
#     onclick="_output_onclick_kzstzxmalfefmazndmhy(0)"
#     onmouseover="_output_onmouseover_kzstzxmalfefmazndmhy(0, this);">Introvert</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.06195286195286207); border-radius: 3px; padding: 0px" id="_tp_kzstzxmalfefmazndmhy_output_1_name"
#     onclick="_output_onclick_kzstzxmalfefmazndmhy(1)"
#     onmouseover="_output_onmouseover_kzstzxmalfefmazndmhy(1, this);">Extrovert</div><br><br><div id='_tp_kzstzxmalfefmazndmhy_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999939028787%" y1="33" x2="49.99999939028787%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999939028787%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="39.38718882021976%" y1="33" x2="39.38718882021976%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.38718882021976%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="28.77437825015165%" y1="33" x2="28.77437825015165%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.77437825015165%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.16156768008354%" y1="33" x2="18.16156768008354%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.16156768008354%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="7.548757110015438%" y1="33" x2="7.548757110015438%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="7.548757110015438%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="60.612809960355975%" y1="33" x2="60.612809960355975%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.612809960355975%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="71.22562053042408%" y1="33" x2="71.22562053042408%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="71.22562053042408%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="81.8384311004922%" y1="33" x2="81.8384311004922%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.8384311004922%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="92.4512416705603%" y1="33" x2="92.4512416705603%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="92.4512416705603%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="57.28427765276698%" y1="33" x2="57.28427765276698%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="57.28427765276698%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.568637</text><text x="57.28427765276698%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.568637</text><text x="57.28427765276698%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="96.11674551089199%" y1="33" x2="96.11674551089199%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="96.11674551089199%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.934538</text><text x="96.11674551089199%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.934538</text><text x="96.11674551089199%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Introvert</tspan>(inputs)</text><rect x="57.284272117754945%" width="38.83247339313705%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="81.8455274 ...

# %%
shap.plots.bar(shap_values_IE[0,:,0], clustering_cutoff=0)

# %%
shap.plots.text(shap_values_TF)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_biieparuuxsliqjmmrjb = '_tp_biieparuuxsliqjmmrjb_output_0';
#     document._zoom_biieparuuxsliqjmmrjb = undefined;
#     function _output_onclick_biieparuuxsliqjmmrjb(i) {
#         var next_id = undefined;
#
#         if (document._zoom_biieparuuxsliqjmmrjb !== undefined) {
#             document.getElementById(document._zoom_biieparuuxsliqjmmrjb+ '_zoom').style.display = 'none';
#
#             if (document._zoom_biieparuuxsliqjmmrjb === '_tp_biieparuuxsliqjmmrjb_output_' + i) {
#                 document.getElementById(document._zoom_biieparuuxsliqjmmrjb).style.display = 'block';
#                 document.getElementById(document._zoom_biieparuuxsliqjmmrjb+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_biieparuuxsliqjmmrjb).style.display = 'none';
#                 document.getElementById(document._zoom_biieparuuxsliqjmmrjb+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_biieparuuxsliqjmmrjb !== '_tp_biieparuuxsliqjmmrjb_output_' + i) {
#             next_id = '_tp_biieparuuxsliqjmmrjb_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_biieparuuxsliqjmmrjb = next_id;
#     }
#     function _output_onmouseover_biieparuuxsliqjmmrjb(i, el) {
#         if (document._zoom_biieparuuxsliqjmmrjb !== undefined) { return; }
#         if (document._hover_biieparuuxsliqjmmrjb !== undefined) {
#             document.getElementById(document._hover_biieparuuxsliqjmmrjb + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_biieparuuxsliqjmmrjb).style.display = 'none';
#         }
#         document.getElementById('_tp_biieparuuxsliqjmmrjb_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_biieparuuxsliqjmmrjb = '_tp_biieparuuxsliqjmmrjb_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.02253911665676371); border-radius: 3px; padding: 0px" id="_tp_biieparuuxsliqjmmrjb_output_0_name"
#     onclick="_output_onclick_biieparuuxsliqjmmrjb(0)"
#     onmouseover="_output_onmouseover_biieparuuxsliqjmmrjb(0, this);">Thinking</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_biieparuuxsliqjmmrjb_output_1_name"
#     onclick="_output_onclick_biieparuuxsliqjmmrjb(1)"
#     onmouseover="_output_onmouseover_biieparuuxsliqjmmrjb(1, this);">Feeling</div><br><br><div id='_tp_biieparuuxsliqjmmrjb_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.999999323804055%" y1="33" x2="49.999999323804055%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.999999323804055%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.07537974076942%" y1="33" x2="34.07537974076942%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.07537974076942%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.150760157734787%" y1="33" x2="18.150760157734787%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.150760157734787%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="65.92461890683869%" y1="33" x2="65.92461890683869%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.92461890683869%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="81.84923848987334%" y1="33" x2="81.84923848987334%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.84923848987334%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="59.62952897196791%" y1="33" x2="59.62952897196791%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.62952897196791%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.620939</text><text x="59.62952897196791%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.620939</text><text x="59.62952897196791%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="12.21397002505184%" y1="33" x2="12.21397002505184%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.21397002505184%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.0254388</text><text x="12.21397002505184%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.0254388</text><text x="12.21397002505184%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Thinking</tspan>(inputs)</text><rect x="5.9869582497516465%" width="6.227011775300193%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.14055835598738%" x2="12.21397002505184%" y1="60" y2="60" id="_fb_azluyunqwdgyaosvqtyp_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="10.17726419051961%" y="71" font-size="12px" id="_fs_azluyunqwdgyaosvqtyp_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.051</text><svg x="8.14055835598738%" y="40" height="20" width="4.073411669064459%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">generally</text>  </svg></svg><line x1="6.920470043122897%" x2="8.14055835598738%" y1="60" y2="60" id="_fb_azluyunqwdgyaosvqtyp_ind_28" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="7.530514199555139%" y="71" font-size="12px" id="_fs_azluyunqwdgyaosvqtyp_ind_28" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor ...

# %%
shap.plots.bar(shap_values_TF[0,:,0], clustering_cutoff=0)

# %%
# text3 to test NS
text3="I am a very logical person and I like to think about things before I act. I am very analytical and I like to solve problems."

shap_values_NS= model.explain_model(model_no_words,[text3],aspect='NS')

# %%
# plot the text explanation
shap.plots.text(shap_values_NS)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_pcqudmaqszrfneorcffk = '_tp_pcqudmaqszrfneorcffk_output_0';
#     document._zoom_pcqudmaqszrfneorcffk = undefined;
#     function _output_onclick_pcqudmaqszrfneorcffk(i) {
#         var next_id = undefined;
#
#         if (document._zoom_pcqudmaqszrfneorcffk !== undefined) {
#             document.getElementById(document._zoom_pcqudmaqszrfneorcffk+ '_zoom').style.display = 'none';
#
#             if (document._zoom_pcqudmaqszrfneorcffk === '_tp_pcqudmaqszrfneorcffk_output_' + i) {
#                 document.getElementById(document._zoom_pcqudmaqszrfneorcffk).style.display = 'block';
#                 document.getElementById(document._zoom_pcqudmaqszrfneorcffk+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_pcqudmaqszrfneorcffk).style.display = 'none';
#                 document.getElementById(document._zoom_pcqudmaqszrfneorcffk+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_pcqudmaqszrfneorcffk !== '_tp_pcqudmaqszrfneorcffk_output_' + i) {
#             next_id = '_tp_pcqudmaqszrfneorcffk_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_pcqudmaqszrfneorcffk = next_id;
#     }
#     function _output_onmouseover_pcqudmaqszrfneorcffk(i, el) {
#         if (document._zoom_pcqudmaqszrfneorcffk !== undefined) { return; }
#         if (document._hover_pcqudmaqszrfneorcffk !== undefined) {
#             document.getElementById(document._hover_pcqudmaqszrfneorcffk + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_pcqudmaqszrfneorcffk).style.display = 'none';
#         }
#         document.getElementById('_tp_pcqudmaqszrfneorcffk_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_pcqudmaqszrfneorcffk = '_tp_pcqudmaqszrfneorcffk_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_pcqudmaqszrfneorcffk_output_0_name"
#     onclick="_output_onclick_pcqudmaqszrfneorcffk(0)"
#     onmouseover="_output_onmouseover_pcqudmaqszrfneorcffk(0, this);">Intuition</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.02253911665676371); border-radius: 3px; padding: 0px" id="_tp_pcqudmaqszrfneorcffk_output_1_name"
#     onclick="_output_onclick_pcqudmaqszrfneorcffk(1)"
#     onmouseover="_output_onmouseover_pcqudmaqszrfneorcffk(1, this);">Sensing</div><br><br><div id='_tp_pcqudmaqszrfneorcffk_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999871368135%" y1="33" x2="49.99999871368135%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999871368135%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="40.269109370679544%" y1="33" x2="40.269109370679544%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="40.269109370679544%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="30.53822002767773%" y1="33" x2="30.53822002767773%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.53822002767773%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="20.80733068467591%" y1="33" x2="20.80733068467591%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.80733068467591%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="11.0764413416741%" y1="33" x2="11.0764413416741%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="11.0764413416741%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="59.73088805668316%" y1="33" x2="59.73088805668316%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.73088805668316%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="69.46177739968498%" y1="33" x2="69.46177739968498%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.46177739968498%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="79.1926667426868%" y1="33" x2="79.1926667426868%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.1926667426868%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="88.92355608568862%" y1="33" x2="88.92355608568862%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="88.92355608568862%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="68.54218220545165%" y1="33" x2="68.54218220545165%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.54218220545165%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.69055</text><text x="68.54218220545165%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.69055</text><text x="68.54218220545165%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="96.08188011744667%" y1="33" x2="96.08188011744667%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="96.08188011744667%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.973563</text><text x="96.08188011744667%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.973563</text><text x="96.08188011744667%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Intuition</tspan>(inputs)</text><rect x="67.5720579402309%" width="28.50982217721577%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="87.4250312528299 ...

# %%
# text to test JP on judging
text4="I judge people based on their actions and I like to plan things ahead of time. I am very organized and I like to have a plan for everything."
shap_values_JP= model.explain_model(model_no_words,[text4],aspect='JP')

# %%
shap.plots.text(shap_values_JP)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_pfvtyagnzyrwiljjyhbw = '_tp_pfvtyagnzyrwiljjyhbw_output_0';
#     document._zoom_pfvtyagnzyrwiljjyhbw = undefined;
#     function _output_onclick_pfvtyagnzyrwiljjyhbw(i) {
#         var next_id = undefined;
#
#         if (document._zoom_pfvtyagnzyrwiljjyhbw !== undefined) {
#             document.getElementById(document._zoom_pfvtyagnzyrwiljjyhbw+ '_zoom').style.display = 'none';
#
#             if (document._zoom_pfvtyagnzyrwiljjyhbw === '_tp_pfvtyagnzyrwiljjyhbw_output_' + i) {
#                 document.getElementById(document._zoom_pfvtyagnzyrwiljjyhbw).style.display = 'block';
#                 document.getElementById(document._zoom_pfvtyagnzyrwiljjyhbw+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_pfvtyagnzyrwiljjyhbw).style.display = 'none';
#                 document.getElementById(document._zoom_pfvtyagnzyrwiljjyhbw+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_pfvtyagnzyrwiljjyhbw !== '_tp_pfvtyagnzyrwiljjyhbw_output_' + i) {
#             next_id = '_tp_pfvtyagnzyrwiljjyhbw_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_pfvtyagnzyrwiljjyhbw = next_id;
#     }
#     function _output_onmouseover_pfvtyagnzyrwiljjyhbw(i, el) {
#         if (document._zoom_pfvtyagnzyrwiljjyhbw !== undefined) { return; }
#         if (document._hover_pfvtyagnzyrwiljjyhbw !== undefined) {
#             document.getElementById(document._hover_pfvtyagnzyrwiljjyhbw + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_pfvtyagnzyrwiljjyhbw).style.display = 'none';
#         }
#         document.getElementById('_tp_pfvtyagnzyrwiljjyhbw_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_pfvtyagnzyrwiljjyhbw = '_tp_pfvtyagnzyrwiljjyhbw_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_pfvtyagnzyrwiljjyhbw_output_0_name"
#     onclick="_output_onclick_pfvtyagnzyrwiljjyhbw(0)"
#     onmouseover="_output_onmouseover_pfvtyagnzyrwiljjyhbw(0, this);">Judging</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.41667656961774624); border-radius: 3px; padding: 0px" id="_tp_pfvtyagnzyrwiljjyhbw_output_1_name"
#     onclick="_output_onclick_pfvtyagnzyrwiljjyhbw(1)"
#     onmouseover="_output_onmouseover_pfvtyagnzyrwiljjyhbw(1, this);">Perceiving</div><br><br><div id='_tp_pfvtyagnzyrwiljjyhbw_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.000000141453704%" y1="33" x2="50.000000141453704%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.000000141453704%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="40.08126029195184%" y1="33" x2="40.08126029195184%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="40.08126029195184%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="30.162520442449978%" y1="33" x2="30.162520442449978%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.162520442449978%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="20.243780592948106%" y1="33" x2="20.243780592948106%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.243780592948106%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="10.325040743446241%" y1="33" x2="10.325040743446241%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.325040743446241%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="59.91873999095557%" y1="33" x2="59.91873999095557%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.91873999095557%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="69.83747984045743%" y1="33" x2="69.83747984045743%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.83747984045743%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="79.75621968995931%" y1="33" x2="79.75621968995931%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.75621968995931%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="89.67495953946117%" y1="33" x2="89.67495953946117%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.67495953946117%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="47.115367160744604%" y1="33" x2="47.115367160744604%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.115367160744604%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.470917</text><text x="47.115367160744604%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.470917</text><text x="47.115367160744604%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="70.20168333282516%" y1="33" x2="70.20168333282516%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="70.20168333282516%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.703672</text><text x="70.20168333282516%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.703672</text><text x="70.20168333282516%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Judging</tspan>(inputs)</text><rect x="24.207297112333926%" width="45.99438622049123%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" />< ...
