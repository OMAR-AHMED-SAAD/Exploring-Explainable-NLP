# %%
# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi

# %% [markdown]
# ## Roberta Base Model

# %%
import os
import pandas as pd
import numpy as np

import torch
from torch.utils.data import Dataset, DataLoader, random_split

from transformers import AutoTokenizer, AutoModel

# %%
# setting the model name
PRE_TRAINED_MODEL_NAME = 'roberta-base'

# setting the dataset
dataset='MBTI 500 multi_label.csv'


# setting the data path
if os.path.exists(f'/datasets/mbti/{dataset}'):
    DATAPATH=f'/datasets/mbti/{dataset}'
else:
    DATAPATH=f'../data/{dataset}'

# setting the checkpoint path 
if os.path.exists('ckpts'):
    CHECKPOINTPATH = 'ckpts/Persnality_MBTI'
else:
    CHECKPOINTPATH = '../ckpts/Persnality_MBTI'

# training parameters
MAX_LEN = 512
TRAIN_BATCH_SIZE = 20
VALID_BATCH_SIZE = 16
TEST_BATCH_SIZE = 16
EPOCHS = 10
THRESHOLD = 0.5 # threshold for the sigmoid function

# TOKENIZER
tokenizer = AutoTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)

# setting the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# setting the random seed
torch.manual_seed(99)
torch.cuda.manual_seed(99)
torch.cuda.manual_seed_all(99)
np.random.seed(99)

# %%
DATAPATH,CHECKPOINTPATH
# Out:
# ('../data/MBTI 500 multi_label.csv', '../ckpts/Persnality_MBTI')

# %% [markdown]
# ### Loading the Data

# %%
# load the data
data = pd.read_csv(DATAPATH,encoding='utf-8')

# %%
# get the labels list
labels_list = data.columns[2:].tolist()
print(f'Labels list: {labels_list}')
# Out:
# Labels list: ['IE', 'NS', 'TF', 'JP']

# %% [markdown]
# #### Load the model

# %%
# import model
import sys
sys.path.append('../Models')
import MBTI_model_shap as model
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/omarahmed/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/omarahmed/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
model_no_words = model.ROBERTAClass(PRE_TRAINED_MODEL_NAME)
model_no_words.load_state_dict(torch.load(CHECKPOINTPATH + f'_clean_Best_{PRE_TRAINED_MODEL_NAME}.bin', map_location=torch.device(device)))
model_no_words.to(device)
print(f'{PRE_TRAINED_MODEL_NAME}_no_words loaded')
model_no_words.eval()

torch.set_grad_enabled(False)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# roberta-base_no_words loaded

# %% [markdown]
# ### SHAP

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# ### Calculate the SHAP values

# %%
text= "I am a very shy person and I prefer to be alone."

# %%
# shap values "call the model.explain method with the model, text data to explain and aspect"
shap_values_IE= model.explain_model(model_no_words,[text],aspect='IE')

# %%
text2="I think people are generally good and I trust them. I am very empathetic and I like to help others. I am very compassionate and I like to make others feel good."

# %%
shap_values_TF= model.explain_model(model_no_words,[text2],aspect='TF')
# Out:
#   0%|          | 0/498 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# PartitionExplainer explainer: 2it [00:11, 11.15s/it]

# %%
model_no_words.getProbabilities(np.array([text]))
# Out:
# tensor([[0.0655, 0.2378, 0.3937, 0.2727]])

# %% [markdown]
# ### Plot the shap values

# %%
shap.plots.text(shap_values_IE)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_wancdnpkciehqytsmarj = '_tp_wancdnpkciehqytsmarj_output_0';
#     document._zoom_wancdnpkciehqytsmarj = undefined;
#     function _output_onclick_wancdnpkciehqytsmarj(i) {
#         var next_id = undefined;
#
#         if (document._zoom_wancdnpkciehqytsmarj !== undefined) {
#             document.getElementById(document._zoom_wancdnpkciehqytsmarj+ '_zoom').style.display = 'none';
#
#             if (document._zoom_wancdnpkciehqytsmarj === '_tp_wancdnpkciehqytsmarj_output_' + i) {
#                 document.getElementById(document._zoom_wancdnpkciehqytsmarj).style.display = 'block';
#                 document.getElementById(document._zoom_wancdnpkciehqytsmarj+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_wancdnpkciehqytsmarj).style.display = 'none';
#                 document.getElementById(document._zoom_wancdnpkciehqytsmarj+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_wancdnpkciehqytsmarj !== '_tp_wancdnpkciehqytsmarj_output_' + i) {
#             next_id = '_tp_wancdnpkciehqytsmarj_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_wancdnpkciehqytsmarj = next_id;
#     }
#     function _output_onmouseover_wancdnpkciehqytsmarj(i, el) {
#         if (document._zoom_wancdnpkciehqytsmarj !== undefined) { return; }
#         if (document._hover_wancdnpkciehqytsmarj !== undefined) {
#             document.getElementById(document._hover_wancdnpkciehqytsmarj + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_wancdnpkciehqytsmarj).style.display = 'none';
#         }
#         document.getElementById('_tp_wancdnpkciehqytsmarj_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_wancdnpkciehqytsmarj = '_tp_wancdnpkciehqytsmarj_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_wancdnpkciehqytsmarj_output_0_name"
#     onclick="_output_onclick_wancdnpkciehqytsmarj(0)"
#     onmouseover="_output_onmouseover_wancdnpkciehqytsmarj(0, this);">Introvert</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.06195286195286207); border-radius: 3px; padding: 0px" id="_tp_wancdnpkciehqytsmarj_output_1_name"
#     onclick="_output_onclick_wancdnpkciehqytsmarj(1)"
#     onmouseover="_output_onmouseover_wancdnpkciehqytsmarj(1, this);">Extrovert</div><br><br><div id='_tp_wancdnpkciehqytsmarj_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.999999192608016%" y1="33" x2="49.999999192608016%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.999999192608016%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="39.38717736923256%" y1="33" x2="39.38717736923256%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.38717736923256%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="28.7743555458571%" y1="33" x2="28.7743555458571%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.7743555458571%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.16153372248164%" y1="33" x2="18.16153372248164%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.16153372248164%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="7.548711899106186%" y1="33" x2="7.548711899106186%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="7.548711899106186%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="60.612821015983464%" y1="33" x2="60.612821015983464%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.612821015983464%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="71.22564283935891%" y1="33" x2="71.22564283935891%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="71.22564283935891%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="81.83846466273438%" y1="33" x2="81.83846466273438%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.83846466273438%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="92.45128648610984%" y1="33" x2="92.45128648610984%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="92.45128648610984%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="57.28425987604195%" y1="33" x2="57.28425987604195%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="57.28425987604195%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.568636</text><text x="57.28425987604195%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.568636</text><text x="57.28425987604195%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="96.11674993302002%" y1="33" x2="96.11674993302002%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="96.11674993302002%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.934538</text><text x="96.11674993302002%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.934538</text><text x="96.11674993302002%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Introvert</tspan>(inputs)</text><rect x="57.28425987604195%" width="38.83249005697805%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="81.84 ...

# %%
shap.plots.bar(shap_values_IE[0,:,0], clustering_cutoff=0)

# %%
shap.plots.text(shap_values_TF)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_tvtojbzsznftbhmkjtwe = '_tp_tvtojbzsznftbhmkjtwe_output_0';
#     document._zoom_tvtojbzsznftbhmkjtwe = undefined;
#     function _output_onclick_tvtojbzsznftbhmkjtwe(i) {
#         var next_id = undefined;
#
#         if (document._zoom_tvtojbzsznftbhmkjtwe !== undefined) {
#             document.getElementById(document._zoom_tvtojbzsznftbhmkjtwe+ '_zoom').style.display = 'none';
#
#             if (document._zoom_tvtojbzsznftbhmkjtwe === '_tp_tvtojbzsznftbhmkjtwe_output_' + i) {
#                 document.getElementById(document._zoom_tvtojbzsznftbhmkjtwe).style.display = 'block';
#                 document.getElementById(document._zoom_tvtojbzsznftbhmkjtwe+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_tvtojbzsznftbhmkjtwe).style.display = 'none';
#                 document.getElementById(document._zoom_tvtojbzsznftbhmkjtwe+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_tvtojbzsznftbhmkjtwe !== '_tp_tvtojbzsznftbhmkjtwe_output_' + i) {
#             next_id = '_tp_tvtojbzsznftbhmkjtwe_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_tvtojbzsznftbhmkjtwe = next_id;
#     }
#     function _output_onmouseover_tvtojbzsznftbhmkjtwe(i, el) {
#         if (document._zoom_tvtojbzsznftbhmkjtwe !== undefined) { return; }
#         if (document._hover_tvtojbzsznftbhmkjtwe !== undefined) {
#             document.getElementById(document._hover_tvtojbzsznftbhmkjtwe + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_tvtojbzsznftbhmkjtwe).style.display = 'none';
#         }
#         document.getElementById('_tp_tvtojbzsznftbhmkjtwe_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_tvtojbzsznftbhmkjtwe = '_tp_tvtojbzsznftbhmkjtwe_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.02253911665676371); border-radius: 3px; padding: 0px" id="_tp_tvtojbzsznftbhmkjtwe_output_0_name"
#     onclick="_output_onclick_tvtojbzsznftbhmkjtwe(0)"
#     onmouseover="_output_onmouseover_tvtojbzsznftbhmkjtwe(0, this);">Thinking</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_tvtojbzsznftbhmkjtwe_output_1_name"
#     onclick="_output_onclick_tvtojbzsznftbhmkjtwe(1)"
#     onmouseover="_output_onmouseover_tvtojbzsznftbhmkjtwe(1, this);">Feeling</div><br><br><div id='_tp_tvtojbzsznftbhmkjtwe_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999981693336%" y1="33" x2="49.99999981693336%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999981693336%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.075376827039584%" y1="33" x2="34.075376827039584%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.075376827039584%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.150753837145807%" y1="33" x2="18.150753837145807%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.150753837145807%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="65.92462280682713%" y1="33" x2="65.92462280682713%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.92462280682713%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="81.84924579672091%" y1="33" x2="81.84924579672091%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.84924579672091%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="59.629493557946276%" y1="33" x2="59.629493557946276%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.629493557946276%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.620938</text><text x="59.629493557946276%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.620938</text><text x="59.629493557946276%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="12.213962434366099%" y1="33" x2="12.213962434366099%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.213962434366099%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.0254388</text><text x="12.213962434366099%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.0254388</text><text x="12.213962434366099%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Thinking</tspan>(inputs)</text><rect x="5.986954666026031%" width="6.227007768340068%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.140549597230535%" x2="12.213962434366099%" y1="60" y2="60" id="_fb_zezaradbcmefkallpftn_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="10.177256015798317%" y="71" font-size="12px" id="_fs_zezaradbcmefkallpftn_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.051</text><svg x="8.140549597230535%" y="40" height="20" width="4.073412837135564%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">generally</text>  </svg></svg><line x1="6.920465176013541%" x2="8.140549597230535%" y1="60" y2="60" id="_fb_zezaradbcmefkallpftn_ind_28" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="7.530507386622038%" y="71" font-size="12px" id="_fs_zezaradbcmefkallpftn_ind_28" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middl ...

# %%
shap.plots.bar(shap_values_TF[0,:,0], clustering_cutoff=0)
